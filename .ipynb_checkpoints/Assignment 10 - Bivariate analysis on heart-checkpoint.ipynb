# %% [markdown]
# # Portfolio assignment 10
# 15 min: Perform a bivariate analysis (Pearson correlation and scatter plot) on at least 1 combination of 2 columns with numeric data in the dataset that you chose in portfolio assignment 4. Does the correlation and scatter plot match your expectations? Add your answer to your notebook. Commit the Notebook to your portfolio when you're finished.

# %% [markdown]
# ### Attibute information
# - age
# - sex
# - chest pain type (4 values)
# - resting blood pressure
# - serum cholestoral in mg/dl
# - fasting blood sugar > 120 mg/dl
# - resting electrocardiographic results (values 0,1,2)
# - maximum heart rate achieved
# - exercise induced angina
# - oldpeak = ST depression induced by exercise relative to rest
# - the slope of the peak exercise ST segment
# - number of major vessels (0-3) colored by flourosopy
# - thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
# - The names and social security numbers of the patients were recently removed from the database, replaced with dummy values.

# %%
import pandas as pd

# %%
heart = pd.read_csv('Assignment 4 - Heart.csv', sep=',')

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
heartCorr = heart.corr()
heartCorr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_37647d82_6b8e_11eb_afa8_0068ebda5a45row0_col0,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row1_col1,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row2_col2,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row3_col3,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row4_col4,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row5_col5,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row6_col6,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row7_col7,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row8_col8,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row9_col9,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row10_col10,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row11_col11,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row12_col12,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row0_col1,#T_37647d82_6b8e_11eb_afa8_0068ebda5a45row1_col0{
#             background-color:  #9fbfff;
#             color:  #000000;
# ...

# %%
heartCorr.plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Strongest positive correlation

# %%
heart.plot(kind='scatter', x='cp', y='target')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='target'>

# %% [markdown]
# ## Strongest negative correlation

# %%
heart.plot(kind='scatter', x='slope', y='oldpeak')
# Out:
# <AxesSubplot:xlabel='slope', ylabel='oldpeak'>

# %% [markdown]
# ## Weakest correlation

# %%
heart.plot(kind='scatter', x='slope', y='chol')
# Out:
# <AxesSubplot:xlabel='slope', ylabel='chol'>

# %% [markdown]
# #### In alle data komt naar voren dat er niet echt een duidelijk verband is tussen de verschillende colommen. Dit valt op. Ik had verwacht dat bijvoorbeeld de maximum hardslag wel een verband zou hebben met de leeftijd van iemand.

# %% [markdown]
# # Transforming the data

# %%
heart.sex = heart.sex.map( {0:"Female" , 1:"Male"} )

# %%
heart.fbs = heart.fbs.map( {0:False , 1:True} )

# %%
heart.exang = heart.exang.map( {0:False , 1:True} )

# %%
heart.target = heart.target.map( {0:"No diseas", 1:"Disease"})

# %%
heart.thal = heart.thal.map( {0:"Normal", 1:"Fixed defect", 2:"Reversable defect"})

# %%
heart.cp = heart.cp.map( {0:"None", 1:"Minor", 2:"Severe", 3:"Major"})

# %%
heart.slope = heart.slope.map( {0:"None", 1:"Minor", 2:"Major"})

# %%
heart.head()
# Out:
#    age     sex      cp  trestbps  chol    fbs  restecg  thalach  exang  \
# 0   63    Male   Major       145   233   True        0      150  False
# 1   37    Male  Severe       130   250  False        1      187  False
# 2   41  Female   Minor       130   204  False        0      172  False
# 3   56    Male   Minor       120   236  False        1      178  False
# 4   57  Female    None       120   354  False        1      163   True
#
#    oldpeak  slope  ca               thal   target
# 0      2.3   None   0       Fixed defect  Disease
# 1      3.5   None   0  Reversable defect  Disease
# 2      1.4  Major   0  Reversable defect  Disease
# 3      0.8  Major   0  Reversable defect  Disease
# 4      0.6  Major   0  Reversable defect  Disease

# %%
heartCorr = heart.corr()
heartCorr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row0_col0,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row1_col1,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row2_col2,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row3_col3,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row4_col4,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row5_col5,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row6_col6,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row7_col7,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row0_col1,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row1_col0{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row0_col2,#T_37d9d5f7_6b8e_11eb_869d_0068ebda5a45row2_col0{
#             background-color:  #ccd9ed;
#             color:  #000000;
# ...

# %%
heartCorr = heart.corr()
heartCorr.plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Strongest positive correlation

# %%
heart.plot(kind='scatter', x='trestbps', y='age')
# Out:
# <AxesSubplot:xlabel='trestbps', ylabel='age'>

# %% [markdown]
# ## Strongest negative correlation

# %%
heart.plot(kind='scatter', x='thalach', y='age')
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='age'>

# %% [markdown]
# ## Weakest correlation

# %%
heart.plot(kind='scatter', x='thalach', y='chol')
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='chol'>
